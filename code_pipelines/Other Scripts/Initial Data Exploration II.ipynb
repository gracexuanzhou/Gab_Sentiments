td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>15</td></tr><tr><td>44</td></tr><tr><td>10</td></tr><tr><td>23</td></tr><tr><td>8</td></tr><tr><td>8</td></tr><tr><td>5</td></tr><tr><td>5</td></tr><tr><td>39</td></tr><tr><td>5</td></tr><tr><td>12</td></tr><tr><td>7</td></tr><tr><td>13</td></tr><tr><td>10</td></tr><tr><td>34</td></tr><tr><td>4</td></tr><tr><td>1</td></tr><tr><td>24</td></tr><tr><td>1</td></tr><tr><td>51</td></tr><tr><td>39</td></tr><tr><td>15</td></tr><tr><td>17</td></tr><tr><td>12</td></tr><tr><td>12</td></tr><tr><td>4</td></tr><tr><td>2</td></tr><tr><td>1</td></tr><tr><td>28</td></tr><tr><td>10</td></tr><tr><td>6</td></tr><tr><td>25</td></tr><tr><td>5</td></tr><tr><td>43</td></tr><tr><td>1</td></tr><tr><td>24</td></tr><tr><td>25</td></tr><tr><td>58</td></tr><tr><td>10</t ...

# %%
data_chunk.where(F.col("category_details.title").isNotNull()).groupBy("category_details.title").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>count</th></tr></thead><tbody><tr><td>Philosophy</td><td>886</td></tr><tr><td>Science</td><td>1116</td></tr><tr><td>Faith</td><td>1409</td></tr><tr><td>Entertainment</td><td>1877</td></tr><tr><td>Art</td><td>1018</td></tr><tr><td>Sports</td><td>454</td></tr><tr><td>Finance</td><td>522</td></tr><tr><td>Cuisine</td><td>201</td></tr><tr><td>AMA</td><td>16917</td></tr><tr><td>Music</td><td>1021</td></tr><tr><td>Photography</td><td>1411</td></tr><tr><td>Technology</td><td>1324</td></tr><tr><td>Humor</td><td>8152</td></tr><tr><td>Politics</td><td>14535</td></tr><tr><td>News</td><td>20829</td></tr></tbody></table></div>

# %%
data_chunk.filter(F.col("topic.title").isNotNull()).groupBy("topic.title").count().filter(F.col("count") > 500).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>count</th></tr></thead><tbody><tr><td>Memes </td><td>5794</td></tr><tr><td>Pettibone & Sellner Detained UK</td><td>1439</td></tr><tr><td>BritFam</td><td>8244</td></tr><tr><td>MEME WARS</td><td>554</td></tr><tr><td>North Korea</td><td>1717</td></tr><tr><td>Martin Sellner Arrested</td><td>842</td></tr><tr><td>Yountville Shooting</td><td>955</td></tr><tr><td>Deutsch </td><td>4999</td></tr><tr><td>Introduce Yourself</td><td>2939</td></tr><tr><td>South Africa</td><td>514</td></tr><tr><td>Trump Rally</td><td>1104</td></tr><tr><td>Tump Visits Border Wall Prototypes</td><td>522</td></tr><tr><td>Tillerson Ousted</td><td>598</td></tr></tbody></table></div>

# %%
data_chunk.where(F.col("category_details.title").isin(["News", "Politics"])).select("user.username", "score").groupBy("username").sum().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
r><tr><td>Rebelin2deep</td><td>9</td></tr><tr><td>Brokenwing</td><td>17</td></tr><tr><td>Awesome_Trump</td><td>15</td></tr><tr><td>TerdFerguson</td><td>172</td></tr><tr><td>CoreyJMahler</td><td>115</td></tr><tr><td>alvin2all</td><td>1</td></tr><tr><td>Gillis</td><td>4</td></tr><tr><td>jljarvis</td><td>4</td></tr><tr><td>NiteMare817</td><td>23</td></tr><tr><td>Pugpaws</td><td>1</td></tr><tr><td>FreeAgent355</td><td>5</td></tr><tr><td>Tyrannyh8r</td><td>11</td></tr><tr><td>Jeanfreau</td><td>27</td></tr><tr><td>AriShekelstein</td><td>418</td></tr><tr><td>Spence66</td><td>4</td></tr><tr><td>DrTrigger</td><td>111</td></tr><tr><td>Fahrenheit88</td><td>4</td></tr><tr><td>HypocrisyHater</td><td>51</td></tr><tr><td>Western_Nationalist</td><td>9</td></tr><tr><td>PryYour3rdEye</td><td>258</td></tr><tr><td>DrPatReads</td><td>210</td></tr><tr><td>Surfishy888</td><td>11</td></tr><tr><td>sunbaby</td><td>3</td></tr><tr><td>Hbomb</td><td>101</td></tr><tr><td>JIH1774</td><td>9</td></tr><tr><td>Travis_Hawks</td><td>41</td></tr><tr><td>hunbun</td><td>149</td></tr><tr><td>CycloneBee</t ...

# %%
data_chunk_filtered = data_chunk.filter((F.col("word_count") > 10) & (F.col("is_reply") == False) & (F.col("only_emoji") == False) & (F.col("category_details.title").isin(["Politics", "News"])) & (F.col("topic.title").isNotNull()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_chunk_filtered.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 4361</div>

# %%
# stuff we'll need for text processing
from nltk.corpus import stopwords
import re as re
from pyspark.ml.feature import CountVectorizer , IDF
# stuff we'll need for building the model

from pyspark.mllib.linalg import Vector, Vectors
from pyspark.mllib.clustering import LDA, LDAModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
StopWords = stopwords.words("english")
def stop_words_filter(x):
    return (~x.isin(StopWords)) & (x.isNotNull()) & (F.length(x) > 2)

data_chunk_tokens = data_chunk_filtered.withColumn('tokens', F.filter(F.split(F.lower(F.col('body')), ' '), stop_words_filter))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_chunk_tokens = data_chunk_tokens.filter(F.size(F.col('tokens')) > 2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_chunk_tokens.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 4361</div>

# %%
cv = CountVectorizer(inputCol="tokens", outputCol="raw_features", vocabSize=5000, minDF=10.0)
cvmodel = cv.fit(data_chunk_tokens)
result_cv = cvmodel.transform(data_chunk_tokens)
# IDF
idf = IDF(inputCol="raw_features", outputCol="features")
idfModel = idf.fit(result_cv)
result_tfidf = idfModel.transform(result_cv)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.mllib.linalg import Vectors as MLlibVectors
num_topics = 10
max_iterations = 100

lda_model = LDA.train(result_tfidf.select("id", "features").rdd.mapValues(MLlibVectors.fromML).map(list), k=num_topics, maxIterations=max_iterations)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_tfidf.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [(&#39;_corrupt_record&#39;, &#39;string&#39;),
#  (&#39;attachment&#39;, &#39;struct&lt;type:string,value:string&gt;&#39;),
#  (&#39;body&#39;, &#39;string&#39;),
#  (&#39;body_html&#39;, &#39;string&#39;),
#  (&#39;body_html_summary&#39;, &#39;string&#39;),
#  (&#39;body_html_summary_truncated&#39;, &#39;boolean&#39;),
#  (&#39;bookmarked&#39;, &#39;boolean&#39;),
#  (&#39;category&#39;, &#39;bigint&#39;),
#  (&#39;category_details&#39;,
#   &#39;struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;&#39;),
#  (&#39;conversation_parent&#39;,
#   &#39;struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint&gt;,conversation_parent:struct&lt;attachment:struct&lt;type:string,value:string&gt;,body:string,body_html:string,body_html_summary:string,body_html_summary_truncated:boolean,bookmarked:boolean,category:bigint,category_details:struct&lt;emoji:string,slug:string,title:string,value:bigint ...

# %%
vocabArray = cvmodel.vocabulary
wordNumbers = 5  
topicIndices = sc.parallelize(lda_model.describeTopics(maxTermsPerTopic = wordNumbers))
def topic_render(topic):
    terms = topic[0]
    result = []
    for i in range(wordNumbers):
        term = vocabArray[terms[i]]
        result.append(term)
    return result
topics_final = topicIndices.map(lambda topic: topic_render(topic)).collect()
for topic in range(len(topics_final)):
    print ("Topic" + str(topic) + ":")
    for term in topics_final[topic]:
        print (term)
    print ('\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;like&#39;, &#39;trump&#39;, &#39;people&#39;, &#39;get&#39;, &#39;\\u00a0&#39;, &#39;would&#39;, &#39;one&#39;, &#39;freedom&#39;, &#39;know&#39;, &#39;white&#39;, &#39;der&#39;, &#39;going&#39;, &#39;ende&#39;, &#39;speech&#39;, &#39;think&#39;, &#39;even&#39;, &#39;want&#39;, &#39;make&#39;, &#39;new&#39;, &#39;see&#39;, &#39;need&#39;, &#39;right&#39;, &#39;time&#39;, &#39;take&#39;, &#34;i&#39;m&#34;, &#39;never&#39;, &#39;every&#39;, &#39;good&#39;, &#39;die&#39;, &#39;back&#39;, &#39;jews&#39;, &#39;many&#39;, &#39;south&#39;, &#39;president&#39;, &#39;gun&#39;, &#39;state&#39;, &#39;spread&#39;, &#34;that&#39;s&#34;, &#39;#freepettibone&#39;, &#39;#freesellner&#39;, &#39;them!&#39;, &#39;#freemartin&#39;, &#39;must&#39;, &#39;#freebrittany&#39;, &#39;war&#39;, &#39;ist&#39;, &#39;meinungsfreiheit&#39;, &#39;#identit\\u00e4r&#39;, &#39;verbreite&#39;, &#39;#gi&#39;, &#39;ihnen&#39;, &#39;could&#39;, &#39;say&#39;, &#39;also&#39;, &#39;it.&#39;, &#34;can&#39;t&#34;, &#39;north&#39;, &#39;way&#39;, &#39;free&#39;, &#39;country&#39;, &#39;#sellner&#39;, &#39;got&#39;, &#39;das&#39;, &#39;government&#39;, &#39;much&#39;, &#39;america&#39;, &#39;american&#39;, &#39;believe&#39;, &#39;world&#39;, &#39;cia&#39;, &#39;keep&#39;, &#39;communist&#39;, &#39;come&#39;, &#39;still&#39;, &#39;police&#39;, &#39;well&#39;, &#39;said&#39;, &#39;great&#39;, &#39;real&#39;, &#39;help&#39;, &#39;years&#39;, &#39;#pettibone&#39;, &#39;jewish&#39;, &#39;all\\u00a0\\n\\r\\ndas&#39;, &#39;fucking&#39;, &#39;look&#39;, &#39;give&#39;, &#39;message\\u00a0\\n\\r\\nhilf&#39;, &#39;nach